# %% [markdown]
# Before optimization.
# ```
# Time (%)  Total Time (ns)  Num Calls   Avg (ns)    Med (ns)   Min (ns)  Max (ns)   StdDev (ns)           Name
#  --------  ---------------  ---------  ----------  ----------  --------  ---------  -----------  ----------------------
#      76.5        291110418         22  13232291.7  10073449.0      3240  100159587   21473833.1  poll
#      11.7         44568624         19   2345717.1     73821.0       150   20553565    5087109.8  sem_timedwait
#      10.6         40452217        497     81392.8     13620.0       370    8701643     493771.3  ioctl
#       0.6          2256322         23     98101.0      7701.0       800     714723     239004.5  mmap
#       0.2           891191         27     33007.1      5590.0      3050     546050     103296.5  mmap64
#       0.1           564549         44     12830.7     11001.0      4730      46081       7172.2  open64
#       0.1           225495         31      7274.0      3770.0      1590      34991       8593.7  fopen
#       0.0           182644          4     45661.0     42016.0     35160      63452      13044.8  pthread_create
#       0.0           136944         11     12449.5     12200.0      1320      21911       5748.3  write
#       0.0            74262         10      7426.2      3850.5      1470      40821      11866.3  munmap
#       0.0            53201         26      2046.2        70.0        60      51401      10066.4  fgets
#       0.0            44730          6      7455.0      8310.0      2620      10800       3474.8  open
#       0.0            43630         54       808.0       480.0       160       6710       1178.4  fcntl
#       0.0            34150         23      1484.8      1190.0       520       4440        978.5  fclose
#       0.0            24500         14      1750.0      1255.0       910       4530       1145.8  read
#       0.0            20640          2     10320.0     10320.0      4530      16110       8188.3  socket
#       0.0            15370          1     15370.0     15370.0     15370      15370          0.0  connect
#       0.0            14400          1     14400.0     14400.0     14400      14400          0.0  fflush
#       0.0            10880          4      2720.0      2710.0        70       5390       3054.3  fread
#       0.0             7310          1      7310.0      7310.0      7310       7310          0.0  pipe2
#       0.0             6270         64        98.0       130.0        40        180         50.2  pthread_mutex_trylock
#       0.0             2510          4       627.5       200.0       130       1980        904.1  fwrite
#       0.0             2390          1      2390.0      2390.0      2390       2390          0.0  bind
#       0.0             1500          1      1500.0      1500.0      1500       1500          0.0  listen
#       0.0              340          1       340.0       340.0       340        340          0.0  pthread_cond_broadcast
#
# [5/8] Executing 'cuda_api_sum' stats report
#
#  Time (%)  Total Time (ns)  Num Calls   Avg (ns)   Med (ns)  Min (ns)  Max (ns)   StdDev (ns)        Name
#  --------  ---------------  ---------  ----------  --------  --------  ---------  -----------  -----------------
#      92.0        152373984          3  50791328.0   77471.0     21590  152274923   87887375.8  cudaMallocManaged
#       8.0         13268118          3   4422706.0  729243.0    712354   11826521    6411897.4  cudaFree
#       0.0            44141          1     44141.0   44141.0     44141      44141          0.0  cudaLaunchKernel
#
# [6/8] Executing 'cuda_gpu_kern_sum' stats report
#
#  Time (%)  Total Time (ns)  Instances   Avg (ns)    Med (ns)   Min (ns)  Max (ns)  StdDev (ns)             Name
#  --------  ---------------  ---------  ----------  ----------  --------  --------  -----------  --------------------------
#     100.0         11089677          1  11089677.0  11089677.0  11089677  11089677          0.0  saxpy(int *, int *, int *)
#
# [7/8] Executing 'cuda_gpu_mem_time_sum' stats report
#
#  Time (%)  Total Time (ns)  Count  Avg (ns)  Med (ns)  Min (ns)  Max (ns)  StdDev (ns)              Operation
#  --------  ---------------  -----  --------  --------  --------  --------  -----------  ---------------------------------
#     100.0          8103642   2664    3041.9    2143.0      1822     68190       3173.6  [CUDA Unified Memory memcpy HtoD]
#
# [8/8] Executing 'cuda_gpu_mem_size_sum' stats report
#
#  Total (MB)  Count  Avg (MB)  Med (MB)  Min (MB)  Max (MB)  StdDev (MB)              Operation
#  ----------  -----  --------  --------  --------  --------  -----------  ---------------------------------
#      50.332   2664     0.019     0.008     0.004     0.885        0.042  [CUDA Unified Memory memcpy HtoD]
#
# Generated:
#     /dli/task/09-saxpy/report1.nsys-rep
#     /dli/task/09-saxpy/report1.sqlite
#
# ```
#
# After optimizations
#
# ```
# Time (%)  Total Time (ns)  Num Calls  Avg (ns)   Med (ns)   Min (ns)  Max (ns)  StdDev (ns)           Name
#  --------  ---------------  ---------  ---------  ---------  --------  --------  -----------  ----------------------
#      60.9        140754277         16  8797142.3  6138521.0      2370  39076417   10869290.6  poll
#      20.1         46373663        501    92562.2    12140.0       380   9753176     607292.3  ioctl
#      17.3         39970236         14  2855016.9    39526.0       130  20466131    6758590.6  sem_timedwait
#       0.8          1909474         23    83020.6     5690.0       860    802124     209295.4  mmap
#       0.4           882298         27    32677.7     3530.0      2780    548330     103864.0  mmap64
#       0.2           511869         44    11633.4    11050.0      3460     32980       5360.0  open64
#       0.1           256544          4    64136.0    57656.0     35260    105972      30742.6  pthread_create
#       0.1           163671         29     5643.8     3530.0      1330     30760       6234.0  fopen
#       0.1           150721         11    13701.9    14140.0      1580     21800       5202.9  write
#       0.0            54881         26     2110.8       70.0        60     52911      10361.4  fgets
#       0.0            43190          6     7198.3     8480.0      2430     10900       3304.0  open
#       0.0            35220         52      677.3      450.0       160      5300        776.8  fcntl
#       0.0            30382          9     3375.8     2990.0      1740      6571       1597.6  munmap
#       0.0            26371         22     1198.7      970.0       520      3060        638.6  fclose
#       0.0            21550         14     1539.3     1215.0       900      3790        948.0  read
#       0.0            21330          2    10665.0    10665.0      4300     17030       9001.5  socket
#       0.0            13090          1    13090.0    13090.0     13090     13090          0.0  connect
#       0.0            12280          5     2456.0     1170.0        90      7470       3109.1  fread
#       0.0             8020          1     8020.0     8020.0      8020      8020          0.0  pipe2
#       0.0             5950         64       93.0       90.0        40       220         51.1  pthread_mutex_trylock
#       0.0             2440          1     2440.0     2440.0      2440      2440          0.0  bind
#       0.0             1440          1     1440.0     1440.0      1440      1440          0.0  listen
#       0.0              270          1      270.0      270.0       270       270          0.0  pthread_cond_broadcast
#
# [5/8] Executing 'cuda_api_sum' stats report
#
#  Time (%)  Total Time (ns)  Num Calls   Avg (ns)   Med (ns)  Min (ns)  Max (ns)   StdDev (ns)          Name
#  --------  ---------------  ---------  ----------  --------  --------  ---------  -----------  ---------------------
#      95.9        121581668          3  40527222.7   20220.0     17510  121543938   70162533.6  cudaMallocManaged
#       2.5          3211238          4    802809.5  132912.0     55361    2890053    1393372.2  cudaMemPrefetchAsync
#       1.5          1857524          3    619174.7  519969.0    515750     821805     175495.7  cudaFree
#       0.1            71811          1     71811.0   71811.0     71811      71811          0.0  cudaDeviceSynchronize
#       0.0            29731          2     14865.5   14865.5      6130      23601      12353.9  cudaLaunchKernel
#
# [6/8] Executing 'cuda_gpu_kern_sum' stats report
#
#  Time (%)  Total Time (ns)  Instances  Avg (ns)  Med (ns)  Min (ns)  Max (ns)  StdDev (ns)             Name
#  --------  ---------------  ---------  --------  --------  --------  --------  -----------  --------------------------
#      70.4            53888          1   53888.0   53888.0     53888     53888          0.0  init(int *, int *, int *)
#      29.6            22624          1   22624.0   22624.0     22624     22624          0.0  saxpy(int *, int *, int *)
#
# [7/8] Executing 'cuda_gpu_mem_time_sum' stats report
#
#  Time (%)  Total Time (ns)  Count  Avg (ns)  Med (ns)  Min (ns)  Max (ns)  StdDev (ns)              Operation
#  --------  ---------------  -----  --------  --------  --------  --------  -----------  ---------------------------------
#     100.0          1281598      8  160199.8  160160.0    160127    160383        104.9  [CUDA Unified Memory memcpy DtoH]
#
# [8/8] Executing 'cuda_gpu_mem_size_sum' stats report
#
#  Total (MB)  Count  Avg (MB)  Med (MB)  Min (MB)  Max (MB)  StdDev (MB)              Operation
#  ----------  -----  --------  --------  --------  --------  -----------  ---------------------------------
#      16.777      8     2.097     2.097     2.097     2.097        0.000  [CUDA Unified Memory memcpy DtoH]
#
# Generated:
#     /dli/task/09-saxpy/report3.nsys-rep
#     /dli/task/09-saxpy/report3.sqlite
# ```
